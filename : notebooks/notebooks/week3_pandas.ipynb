# %% [markdown]
# <a href="https://colab.research.google.com/github/thesammonmo-bit/ai-engineer-bootcamp/blob/main/%3A%20notebooks/week3_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
df=pd.DataFrame({
    "ner":["Hool","Undaa","Taxi","Bus","Tsuivan"],
    "dun":[20000,3000,5000,1000,15000]
})
plt.bar(df["ner"],df["dun"], color="green")
plt.xlabel("Ner")
plt.ylabel("Dun")
# Out:
# Text(0, 0.5, 'Dun')
